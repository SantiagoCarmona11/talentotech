# %%
import pandas as pd
import sklearn
import seaborn as sns

df = pd.read_csv('regresion.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-2360975661> in <cell line: 0>()
#       3 import seaborn as sns
#       4
# ----> 5 df = pd.read_csv('regresion.csv')
#       6 df.head()
#
# ...

# %% [markdown]
# Metodos
#
# df.discrip()
# df.info()
# df.head() muestra los primeros 5 de una tabla
# df.tail() muestra los ultimos 5 de la tabla
#
# consulta: como visualizar la tabla completa
#
#
# Comandos de regresion lineal
