# %%
diccionario={

    "colombia" : "pais",
    "santiago" : "nombre",
    "perro" : "animal",
    "casa" : "lugar para poder vivir",
    "gato" : "animal"

    }
for elementos_diccionario in diccionario:
  #print(diccionario)
  print(elementos_diccionario)

numeros_celulares_estudiantes =  {3126667212, 3126667212, 3156543215, 3126667212}
print("")
#print(numeros_celulares)
for elementos_conjunto in numeros_celulares_estudiantes:
 #print(numeros_celulares_estudiantes)
  print(elementos_conjunto)

alimentos = ["pollo", "carne", "manzanas", "cebolla", "leche", "huevos"]
print("")
for elementos_lista in alimentos:
 #print(alimentos)
 print(elementos_lista)



numero_cedula_estudiantes = (1081272125, 1081272124, 1098231123, 1234567890)
print("")
for elementos_tupla in numero_cedula_estudiantes:
 #print(numero_cedula_estudiantes)
 print(elementos_tupla)
# Out:
# colombia
# santiago
# perro
# casa
# gato
#
# 3126667212
# 3156543215
#
# pollo
# carne
# manzanas
# cebolla
# leche
# huevos
#
# 1081272125
# 1081272124
# 1098231123
# 1234567890
